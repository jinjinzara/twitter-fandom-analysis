# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 11 16:10:35 2022

@author: rubby
"""

import twitter
import json
import time
import pandas as pd
import networkx as nx
import pickle
import random
import config2 as config
import os.path
import time
from datetime import datetime

twitter_api = twitter.Api(consumer_key=config.twitter_consumer_key,
                              consumer_secret=config.twitter_consumer_secret, 
                              access_token_key=config.twitter_access_token, 
                              access_token_secret=config.twitter_access_secret,
                              sleep_on_rate_limit=True)

most_followed = pd.read_csv('crawling/top100.csv')


def collecting_mention(artist_name, artist_account):
    filepath_n = ('data/network/{}.net'.format(artist_name)).replace('*', ' ').replace('!', '')
    filepath_f = ('data/followers_filtered/{}.p'.format(artist_name)).replace('*', ' ').replace('!', '')
    dir_t = ('data/tweets/{}'.format(artist_name)).replace('*', ' ').replace('!', '')
    avg_tweet_num = 0
    if not os.path.exists(dir_t):
        os.makedirs(dir_t)
    
    if not os.path.isfile(filepath_n):
        with open(filepath_f, 'rb') as f:
            followers = pickle.load(f)
        
        G = nx.Graph()
        
        for follower in followers:
            filepath_t = ('data/tweets/{}/{}.p'.format(artist_name, follower.id)).replace('*', ' ').replace('!', '')
            all_statuses = []
            print('artist: {}, follower: {}/{}'.format(artist_name, followers.index(follower)+1, len(followers)))
            
            last_date = datetime.now()
            last_id = None
            
            try:
                # for test, initialization
                statuses = twitter_api.GetUserTimeline(screen_name=artist_account)
            except Exception as e:
                print(e)
            
            while last_date > datetime(2022,5,1) or statuses:
                try:
                    statuses = twitter_api.GetUserTimeline(user_id=follower.id, max_id=last_id, count=200)
                except Exception as e:
                    print('In GetUserTimeline: {}'.format(e))
                    statuses = []
                    time.sleep(5)
                if statuses:
                    last_status = statuses[-1]
                    last_date = datetime.strptime(last_status.created_at,'%a %b %d %H:%M:%S +0000 %Y')
                    last_id = last_status.id
                    
                    for status in statuses:
                        s_created_date = datetime.strptime(status.created_at,'%a %b %d %H:%M:%S +0000 %Y')
                        
                        if s_created_date < datetime(2022,11,1) and s_created_date >= datetime(2022,5,1):
                            all_statuses.append([status.id, s_created_date, status.text])
                            if status.user_mentions:
                                for mentioned_user in status.user_mentions:
                                    if mentioned_user.id != follower.id:
                                        try:
                                            following = twitter_api.ShowFriendship(source_user_id=mentioned_user.id, 
                                                                                   target_screen_name=artist_account)

                                            if following.get('relationship').get('source').get('following'):
                                                G.add_edge(follower.id, mentioned_user.id)
                                                nx.write_pajek(G, filepath_n)
                                                #print('add edge of {}. date: {}'.format(artist_name, status.created_at))
                                        except Exception as e:
                                            print('In ShowFriendship: {}'.format(e))
                if len(statuses) < 200:
                    break
            with open(filepath_t, 'wb') as f:
                pickle.dump(all_statuses, f)
            
            avg_tweet_num += len(all_statuses) / len(followers)
        
        print('average tweets of {}: {}'.format(artist_name, avg_tweet_num))
    else:
        print('{} network exists'.format(artist_name))


for i in most_followed.index:
    name = most_followed['name'][i]
    acc = most_followed['account'][i]
    collecting_mention(name, acc)
# Out:
# BTS network exists
# artist: EXO, follower: 1/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 2/100
# artist: EXO, follower: 3/100
# artist: EXO, follower: 4/100
# artist: EXO, follower: 5/100
# artist: EXO, follower: 6/100
# artist: EXO, follower: 7/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 8/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 9/100
# artist: EXO, follower: 10/100
# artist: EXO, follower: 11/100
# artist: EXO, follower: 12/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 13/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 14/100
# artist: EXO, follower: 15/100
# artist: EXO, follower: 16/100
# artist: EXO, follower: 17/100
# artist: EXO, follower: 18/100
# artist: EXO, follower: 19/100
# artist: EXO, follower: 20/100
# artist: EXO, follower: 21/100
# In ShowFriendship: [{'code': 163, 'message': 'Could not determine source user.'}]
# artist: EXO, follower: 22/100
# artist: EXO, follower: 23/100
# artist: EXO, follower: 24/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 25/100
# artist: EXO, follower: 26/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 27/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 28/100
# artist: EXO, follower: 29/100
# artist: EXO, follower: 30/100
# artist: EXO, follower: 31/100
# artist: EXO, follower: 32/100
# artist: EXO, follower: 33/100
# artist: EXO, follower: 34/100
# artist: EXO, follower: 35/100
# artist: EXO, follower: 36/100
# artist: EXO, follower: 37/100
# artist: EXO, follower: 38/100
# artist: EXO, follower: 39/100
# artist: EXO, follower: 40/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 41/100
# artist: EXO, follower: 42/100
# artist: EXO, follower: 43/100
# artist: EXO, follower: 44/100
# artist: EXO, follower: 45/100
# artist: EXO, follower: 46/100
# artist: EXO, follower: 47/100
# artist: EXO, follower: 48/100
# artist: EXO, follower: 49/100
# artist: EXO, follower: 50/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 51/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 52/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 53/100
# artist: EXO, follower: 54/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 55/100
# artist: EXO, follower: 56/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 57/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 58/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 59/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 60/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 61/100
# artist: EXO, follower: 62/100
# artist: EXO, follower: 63/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 64/100
# artist: EXO, follower: 65/100
# artist: EXO, follower: 66/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 67/100
# artist: EXO, follower: 68/100
# artist: EXO, follower: 69/100
# artist: EXO, follower: 70/100
# artist: EXO, follower: 71/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 72/100
# artist: EXO, follower: 73/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 74/100
# artist: EXO, follower: 75/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 76/100
# artist: EXO, follower: 77/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 78/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 79/100
# artist: EXO, follower: 80/100
# artist: EXO, follower: 81/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 82/100
# artist: EXO, follower: 83/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 84/100
# artist: EXO, follower: 85/100
# artist: EXO, follower: 86/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 87/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 88/100
# In ShowFriendship: [{'code': 163, 'message': 'Could not determine source user.'}]
# artist: EXO, follower: 89/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 90/100
# artist: EXO, follower: 91/100
# artist: EXO, follower: 92/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 93/100
# artist: EXO, follower: 94/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 95/100
# artist: EXO, follower: 96/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 97/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 98/100
# In GetUserTimeline: Not authorized.
# artist: EXO, follower: 99/100
# artist: EXO, follower: 100/100
# In GetUserTimeline: Not authorized.
# average tweets of EXO: 18.379999999999995
# TWICE network exists
# artist: SEVENTEEN, follower: 1/100
# artist: SEVENTEEN, follower: 2/100
# In GetUserTimeline: Not authorized.
# artist: SEVENTEEN, follower: 3/100
# artist: SEVENTEEN, follower: 4/100
# artist: SEVENTEEN, follower: 5/100
# artist: SEVENTEEN, follower: 6/100
# artist: SEVENTEEN, follower: 7/100
# In GetUserTimeline: Not authorized.
# artist: SEVENTEEN, follower: 8/100
# artist: SEVENTEEN, follower: 9/100
# artist: SEVENTEEN, follower: 10/100
# In GetUserTimeline: Not authorized.
# artist: SEVENTEEN, follower: 11/100
# artist: SEVENTEEN, follower: 12/100
# In GetUserTimeline: Not authorized.
# artist: SEVENTEEN, follower: 13/100
